# %% [markdown]
# <a href="https://colab.research.google.com/github/anujjakhotiya/AI-DL_2026/blob/main/Lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

torch.manual_seed(0)
X = torch.rand(100, 1) * 10
y = 3 * X + 2 + torch.randn(100, 1)
model = nn.Linear(1, 1)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
print(model.weight, model.bias)
for epoch in range(200):
    optimizer.zero_grad()
    y_pred = model(X)
    loss = criterion(y_pred,  y)
    loss.backward()
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}: loss={loss.item():.3f}")
print("Learned weight:", model.weight.item())
print("Learned bias:", model.bias.item())
# Out:
# Parameter containing:
# tensor([[-0.7822]], requires_grad=True) Parameter containing:
# tensor([-0.5241], requires_grad=True)
# Epoch 0: loss=559.985
# Epoch 50: loss=1.583
# Epoch 100: loss=1.262
# Epoch 150: loss=1.072
# Learned weight: 3.0518887042999268
# Learned bias: 1.5383261442184448
